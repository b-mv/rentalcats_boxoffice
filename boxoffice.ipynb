# %%
import pandas as pd
import numpy as np

train = pd.read_csv('data/train.csv')
display(train.head())

# describe columns
display(train.select_dtypes('object').describe().T)
display(train.describe().T.round(2))

print(type(train['genres'][0]))
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ### Missing Values

# %%
# Which columns have missing values and how many?

print('Missing Values: ')

n_nulls = train.isnull().sum()
mask = n_nulls > 0
n_nulls[mask]
# Out:
# Missing Values:
# belongs_to_collection    2396
# genres                      7
# homepage                 2054
# overview                    8
# poster_path                 1
# production_companies      156
# production_countries       55
# runtime                     2
# spoken_languages           20
# tagline                   597
# Keywords                  276
# cast                       13
# crew                       16
# dtype: int64

# %% [markdown]
# ### Value Counts

# %%
pd.DataFrame(train['belongs_to_collection'].value_counts()).head(10)
# Out:
#                                                     belongs_to_collection
# [{'id': 645, 'name': 'James Bond Collection', '...                     16
# [{'id': 9735, 'name': 'Friday the 13th Collecti...                      7
# [{'id': 937, 'name': 'The Pink Panther (Origina...                      6
# [{'id': 9338, 'name': 'Police Academy Collectio...                      5
# [{'id': 34055, 'name': 'Pokémon Collection', 'p...                      5
# [{'id': 5039, 'name': 'Rambo Collection', 'post...                      4
# [{'id': 9485, 'name': 'The Fast and the Furious...                      4
# [{'id': 8091, 'name': 'Alien Collection', 'post...                      4
# [{'id': 1575, 'name': 'Rocky Collection', 'post...                      4
# [{'id': 8354, 'name': 'Ice Age Collection', 'po...                      4

# %%
pd.DataFrame(train['original_language'].value_counts()).head(10)
# Out:
#     original_language
# en               2575
# fr                 78
# ru                 47
# es                 43
# hi                 42
# ja                 37
# it                 24
# ko                 20
# cn                 20
# zh                 19

# %%
pd.DataFrame(train['genres'].value_counts()).head(10)
# Out:
#                                                     genres
# [{'id': 18, 'name': 'Drama'}]                          266
# [{'id': 35, 'name': 'Comedy'}]                         186
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'na...     108
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'n...      88
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...      85
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...      65
# [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name...      47
# [{'id': 99, 'name': 'Documentary'}]                     44
# [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name'...      44
# [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name'...      33

# %%
pd.DataFrame(train['spoken_languages'].value_counts()).head(10)
# Out:
#                                                     spoken_languages
# [{'iso_639_1': 'en', 'name': 'English'}]                        1817
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_...                86
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_...                77
# [{'iso_639_1': 'ru', 'name': 'Pусский'}]                          45
# [{'iso_639_1': 'fr', 'name': 'Français'}]                         40
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_...                34
# [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]                           31
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_...                29
# [{'iso_639_1': 'es', 'name': 'Español'}]                          29
# [{'iso_639_1': 'es', 'name': 'Español'}, {'iso_...                28

# %%
pd.DataFrame(train['production_companies'].value_counts()).head(10)
# Out:
#                                                     production_companies
# [{'name': 'Paramount Pictures', 'id': 4}]                             51
# [{'name': 'Universal Pictures', 'id': 33}]                            36
# [{'name': 'Warner Bros.', 'id': 6194}]                                32
# [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 84...                    32
# [{'name': 'Twentieth Century Fox Film Corporati...                    24
# [{'name': 'Touchstone Pictures', 'id': 9195}]                         17
# [{'name': 'Columbia Pictures', 'id': 5}]                              17
# [{'name': 'New Line Cinema', 'id': 12}]                               17
# [{'name': 'TriStar Pictures', 'id': 559}]                             16
# [{'name': 'Orion Pictures', 'id': 41}]                                12

# %%
pd.DataFrame(train['Keywords'].value_counts()).head(10)
# Out:
#                                                     Keywords
# [{'id': 10183, 'name': 'independent film'}]               27
# [{'id': 187056, 'name': 'woman director'}]                19
# [{'id': 179431, 'name': 'duringcreditsstinger'}]           7
# [{'id': 9937, 'name': 'suspense'}]                         6
# [{'id': 5565, 'name': 'biography'}]                        5
# [{'id': 6075, 'name': 'sport'}]                            4
# [{'id': 10183, 'name': 'independent film'}, {'i...         3
# [{'id': 4565, 'name': 'dystopia'}]                         3
# [{'id': 9799, 'name': 'romantic comedy'}]                  2
# [{'id': 579, 'name': 'american football'}, {'id...         2

# %% [markdown]
# ### Data Clean

# %%
# split release date into year, month, day columns

# convert data type to pandas 'datetime'
train['release_date'] = pd.to_datetime(train['release_date'])

train['release_year'] = train['release_date'].dt.year
train['release_month'] = train['release_date'].dt.month
train['release_day'] = train['release_date'].dt.day
# Out:
#                 count          mean           std          min           25%  \
# id             3000.0  1.500500e+03  8.661697e+02     1.000000  7.507500e+02
# budget         3000.0  2.253133e+07  3.702609e+07     0.000000  0.000000e+00
# popularity     3000.0  8.463274e+00  1.210400e+01     0.000001  4.018053e+00
# runtime        2998.0  1.078566e+02  2.208643e+01     0.000000  9.400000e+01
# revenue        3000.0  6.672585e+07  1.375323e+08     1.000000  2.379808e+06
# release_month  3000.0  6.775333e+00  3.409115e+00     1.000000  4.000000e+00
# release_year   3000.0  2.004580e+03  1.548079e+01  1969.000000  1.995000e+03
# release_day    3000.0  1.504633e+01  8.632981e+00     1.000000  8.000000e+00
#
#                         50%           75%           max
# id             1.500500e+03  2.250250e+03  3.000000e+03
# budget         8.000000e+06  2.900000e+07  3.800000e+08
# popularity     7.374861e+00  1.089098e+01  2.943370e+02
# ...
